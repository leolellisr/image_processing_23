# %% [markdown]
#  # Table of Contents
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item" id="toc-level0"><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Processamento-de-imagens-usando-fatiamento-do-Numpy" data-toc-modified-id="Processamento-de-imagens-usando-fatiamento-do-Numpy-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Processamento de imagens usando fatiamento do Numpy</a></span><ul class="toc-item"><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Sobrepondo-reticulado" data-toc-modified-id="Sobrepondo-reticulado-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Sobrepondo reticulado</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Sobrepondo-frame-preto-na-imagem" data-toc-modified-id="Sobrepondo-frame-preto-na-imagem-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Sobrepondo frame preto na imagem</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Rotação-90-graus" data-toc-modified-id="Rotação-90-graus-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Rotação 90 graus</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Subamostragem" data-toc-modified-id="Subamostragem-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Subamostragem</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Ampliação" data-toc-modified-id="Ampliação-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Ampliação</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Separando-campos-pares-e-impares-entrelaçados" data-toc-modified-id="Separando-campos-pares-e-impares-entrelaçados-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Separando campos pares e impares entrelaçados</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Combinando-duas-imagens-linhas-pares-de-uma-e-ímpares-de-outra" data-toc-modified-id="Combinando-duas-imagens-linhas-pares-de-uma-e-ímpares-de-outra-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Combinando duas imagens linhas pares de uma e ímpares de outra</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Montagem-e-reflexão-vertical-e-horizontal" data-toc-modified-id="Montagem-e-reflexão-vertical-e-horizontal-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Montagem e reflexão vertical e horizontal</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Translação" data-toc-modified-id="Translação-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Translação</a></span></li><li><span><a href="http://localhost:8888/notebooks/ia898/master/tutorial_1_imagens.ipynb#Outros-exemplos" data-toc-modified-id="Outros-exemplos-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Outros exemplos</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Processamento de imagens usando fatiamento do Numpy
#
# Uma introdução sobre como representar, ler e exibir imagens no Adessowiki podem ser vista em:
#
# - `master:tutorial_img_ds Representação, Leitura e Visualização de Imagens no Adessowiki`.
#
# O conceito de fatiamento (slicing) do Numpy é um dos mais importantes para processamento de imagens, tanto
# pela sua versatilidade como pela sua eficiência. Reunimos nesta página um conjunto de processamento de
# imagens utilizando quase que exclusivamente operações de fatiamento.
#
# Para entender melhor como o fatiamento funciona, recomenda-se ver uma explicação didática do fatiamento:
#
# - `tutorial_numpy_1_2 Fatiamentos unidimensionais`
# - `tutorial_numpy_1_3 Fatiamentos bidimensionais`
#
# ## Sobrepondo reticulado

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image
from IPython.display import display

# %%
f = mpimg.imread('../data/cameraman.tif').copy()
display(Image.fromarray(f))
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FD7C0484DF0>

# %%
f[::10,:] = 255 # linhas horizontais
f[:,::10] = 255 # linhas verticais
Image.fromarray(f)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FD784EAA470>

# %% [markdown]
# ## Sobrepondo frame preto na imagem

# %%
f = mpimg.imread('../data/cameraman.tif').copy()
display(Image.fromarray(f))
f[   :10,   :  ] = 0 # frame superior
f[-10:  ,   :  ] = 0 # frame inferior
f[   :  ,   :10] = 0 # frame esquerdo
f[   :  ,-10:  ] = 0 # frame direito
display(Image.fromarray(f))
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FD784E352D0>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FD7C04864D0>

# %% [markdown]
# ## Rotação 90 graus
#
# Uma técnica simples para se fazer uma rotação antihorária da matriz, é calcular a matriz transposta e depois
# refleti-la na vertical:

# %%
f1 = mpimg.imread('../data/cameraman.tif').copy()
f = f1[:,64:192]
print('original shape=%s' % (f.shape,))
Image.fromarray(f)
# Out:
# original shape=(256, 128)
# <PIL.Image.Image image mode=L size=128x256 at 0x7FD7C0486AA0>

# %%
g = f.transpose()
print('transposta shape=%s' % (g.shape,))
Image.fromarray(g)
# Out:
# transposta shape=(128, 256)
# <PIL.Image.Image image mode=L size=256x128 at 0x7FD784EAB220>

# %%
gr = g[::-1,:]
#'reflete na vertical'
Image.fromarray(gr)
# Out:
# <PIL.Image.Image image mode=L size=256x128 at 0x7FD784EAB010>

# %%
gr[:10,:20] = 0
Image.fromarray(gr)
# Out:
# <PIL.Image.Image image mode=L size=256x128 at 0x7FD784EAAE60>

# %% [markdown]
# ## Subamostragem

# %%
g = f1[::2,::2]
print('shape=%s' % (g.shape,) )
display(Image.fromarray(f1))
Image.fromarray(g)
# Out:
# shape=(128, 128)
# <PIL.Image.Image image mode=L size=256x256 at 0x7FD784EAA050>
# <PIL.Image.Image image mode=L size=128x128 at 0x7FD784EAB520>

# %% [markdown]
# ## Ampliação

# %%
f = mpimg.imread('../data/keyb.tif').copy()[:50,:80]
print('original %s' % (f.shape,) )
Image.fromarray(f)
# Out:
# original (50, 80)
# <PIL.Image.Image image mode=L size=80x50 at 0x7FD7C0461F60>

# %%
H,W = f.shape
g = np.zeros( (2*H,2*W), 'uint8')
g[ ::2, ::2] = f
g[1::2, ::2] = f
g[1::2,1::2] = f
g[ ::2,1::2] = f
plt.imshow(g, cmap='gray')
print('ampliada por replicação %s' % (g.shape,) )
print(g)
# Out:
# ampliada por replicação (100, 160)
# [[156 156 165 ... 170 178 178]
#  [156 156 165 ... 170 178 178]
#  [173 173 165 ... 173 181 181]
#  ...
#  [165 165 173 ... 178 165 165]
#  [156 156 165 ... 173 181 181]
#  [156 156 165 ... 173 181 181]]

# %% [markdown]
# ## Separando campos pares e impares entrelaçados

# %%
f = mpimg.imread('../data/tvframe.pgm')[100:350,100:300]
plt.imshow(f, cmap='gray')
print('original com dois campos')
# Out:
# original com dois campos

# %%
g_par = f[::2,:]
plt.imshow(g_par,cmap='gray')

# %%
g_impar = f[1::2,:]
plt.imshow(g_impar,cmap='gray')

# %%
ns1 = np.array(g_par.shape)
ns = ns1 + np.array([g_impar.shape[0], 0])
print(tuple(ns))
# Out:
# (250, 200)

# %%
g = np.empty(ns)
g[:g_par.shape[0]] = g_par
g[g_par.shape[0]:] = g_impar
plt.imshow(g,cmap='gray')

# %% [markdown]
# Reescrevendo o código para torná-lo mais legível

# %%
H_par,W_par = g_par.shape
H_impar,W_impar = g_impar.shape
F = np.empty((H_par+H_impar, W_par))
F[:H_par] = g_par
F[H_par:] = g_impar
plt.imshow(F,cmap='gray')

# %%
g_even = np.zeros_like(f)
g_even[::2] = f[::2]
g_even[1::2] = f[::2]
display(Image.fromarray(g_even))
print('campo linhas pares')
# Out:
# <PIL.Image.Image image mode=L size=200x250 at 0x7FD7813B8A00>
# campo linhas pares

# %%
g_odd = np.zeros_like(f)
g_odd[::2]  = f[1::2]
g_odd[1::2] = f[1::2]
print('campo linhas ímpares')
Image.fromarray(g_odd)
# Out:
# campo linhas ímpares
# <PIL.Image.Image image mode=L size=200x250 at 0x7FD78134A200>

# %% [markdown]
# ## Combinando duas imagens linhas pares de uma e ímpares de outra

# %%
f1 = mpimg.imread('../data/woodlog.tif')
plt.imshow(f1,cmap='gray')
print('f1: woodlog')
# Out:
# f1: woodlog

# %%
f2 = mpimg.imread('../data/keyb.tif')
plt.imshow(f2,cmap='gray')
print('f2: keyb')
# Out:
# f2: keyb

# %%
H,W = np.minimum(np.array(f1.shape),np.array(f2.shape))
g = np.empty((H,W))
g[::2,:] = f1[:H:2,:W]
g[1::2,:] = f2[1:H:2,:W]
plt.imshow(g[:,:],cmap='gray')
print('linhas ímpares de f1 e pares de f2')
# Out:
# linhas ímpares de f1 e pares de f2

# %%
H,W = np.minimum(np.array(f1.shape),np.array(f2.shape))
g = f1[:H,:W]//2 + f2[:H,:W]//2
plt.imshow(g,cmap='gray')
plt.colorbar()
print('combinando f1 + f2 usando cálculo em inteiros')
# Out:
# combinando f1 + f2 usando cálculo em inteiros

# %%
H,W = np.minimum(np.array(f1.shape),np.array(f2.shape))
g = f1[:H,:W]/f1.max() + f2[:H,:W]/f2.max()
plt.imshow(g,cmap='gray')
plt.colorbar()
print('combinando f1 + f2 usando ponto flutuante')
# Out:
# combinando f1 + f2 usando ponto flutuante

# %% [markdown]
# ## Montagem e reflexão vertical e horizontal

# %%
f = mpimg.imread('../data/keyb.tif')[:50,:50]
plt.imshow(f,cmap='gray')
print('original')
# Out:
# original

# %%
H,W = f.shape
g = np.empty( (2*H,2*W), 'uint8')
g[:H,:W] = f          # original no quadrante superior esquerdo
g[H:,:W] = f[::-1,:]  # refletida vertical no quadrante inferior esquerdo
g[:H,W:] = f[:,::-1]  # refletida horizontal no quadrante superior direito
g[H:,W:] = f[::-1,::-1] # refletida vert. e hor. no quadrante inferior direito
plt.imshow(g,cmap='gray') 
print('refletidas')
# Out:
# refletidas

# %% [markdown]
# ## Translação
#
# Uma operação primitiva que é utilizada na construção de várias outras operações é
# a translação de uma imagem por um fator de deslocamento na vertical e na horizontal.
# Numpy permite fazer translações extremamente eficientes utilizando fatiamento. O
# exemplo abaixo, a imagem **g** é deslocada de (dH,dW).

# %%
H,W = 100,200
f = np.zeros((H,W),'uint8')
f[::10,:] = 255
f[:,::10] = 255
plt.imshow(f,cmap='gray')
print('reticulado de passo 10 pixels')
# Out:
# reticulado de passo 10 pixels

# %%
g = mpimg.imread('../data/lenina.pgm').copy()
plt.imshow(g,cmap='gray')

# %%
f = g[:H,:W]
plt.imshow(f,cmap='gray')
print('imagem g na origem (0,0)')
# Out:
# imagem g na origem (0,0)
